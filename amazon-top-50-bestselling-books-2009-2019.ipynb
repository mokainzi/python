# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df_filepath = 'bestsellers with categories.csv'
df = pd.read_csv(df_filepath)

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df.shape
# Out:
# (550, 7)

# %%
sns.distplot(df['Price']) #, kde=False)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(df['User Rating']) #, kde=False)
# Out:
# <AxesSubplot:xlabel='User Rating'>

# %%
sns.distplot(df['Reviews']) #, kde=False)
# Out:
# <AxesSubplot:xlabel='Reviews'>

# %%
sns.barplot(x=df['Genre'], y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Price'>

# %%
plt.figure(figsize=(10,7))
sns.lmplot(data=df,
           x='User Rating', 
           y='Price', 
#            fit_reg=False,
           hue='Genre')
plt.title('User Rating By Book Price')
# Out:
# Text(0.5, 1.0, 'User Rating By Book Price')

# %%
plt.figure(figsize=(10,7))
sns.lmplot(data=df,
           x='Reviews', 
           y='Price', 
#            fit_reg=False,
           hue='Genre')
plt.title('Reviews By Book Price')
plt.xticks(rotation=45)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000., 70000.,
#         80000., 90000.]),
#  [Text(0.0, 0, '0'),
#   Text(10000.0, 0, '10000'),
#   Text(20000.0, 0, '20000'),
#   Text(30000.0, 0, '30000'),
#   Text(40000.0, 0, '40000'),
#   Text(50000.0, 0, '50000'),
#   Text(60000.0, 0, '60000'),
#   Text(70000.0, 0, '70000'),
#   Text(80000.0, 0, '80000'),
#   Text(90000.0, 0, '90000')])

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(x=df['Genre'], y=df['Price'])
plt.title('Book Genre By Price')
# Out:
# Text(0.5, 1.0, 'Book Genre By Price')

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(x=df['Genre'], y=df['Reviews'])
plt.title('Book Genre By Reviews')
# Out:
# Text(0.5, 1.0, 'Book Genre By Reviews')

# %%
plt.figure(figsize=(15,7))

sns.lineplot(x='Year', y='Price', data=df, label='Price')
sns.lineplot(x='Year', y='User Rating', data=df, label='User Rating')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='User Rating'>
